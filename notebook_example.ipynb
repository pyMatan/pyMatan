# %%
from pyMatan.limits_derivatives.limits import visualize_limit

print("Visualization 3: lim(x->0) 1/x (Discontinuity)")
visualize_limit("1/x", x0=0, h_window=2.0)
# Out:
# Visualization 3: lim(x->0) 1/x (Discontinuity)

# %%
from pyMatan.limits_derivatives.derivatives import visualize_derivative
print("Visualization: Comparing Tangent and Secant Lines")

visualize_derivative("x**3 - x", x0=1.0, h_step=0.5, h_approx=0.01)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from pyMatan.limits_derivatives.derivatives import visualize_derivative
#       2 print("Visualization: Comparing Tangent and Secant Lines")
#       4 visualize_derivative("x**3 - x", x0=1.0, h_step=0.5, h_approx=0.01)
#
# ImportError: cannot import name 'visualize_derivative' from 'pyMatan.limits_derivatives.derivatives' (/home/z0nt1x/Стільниця/pyMatan/pyMatan/limits_derivatives/derivatives.py)
